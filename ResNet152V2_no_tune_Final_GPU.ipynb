# %% [markdown]
# # Reference

# %% [markdown]
# Tensorflow
# 1. https://www.tensorflow.org/tutorials/images/classification
# 2. https://www.tensorflow.org/tutorials/load_data/images
# 3. https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
# 4. https://www.tensorflow.org/api_docs/python/tf/keras/Model#predict

# %% [markdown]
# Keras (https://keras.io/api/)
# 1. https://keras.io/examples/vision/image_classification_from_scratch/
# 2. https://keras.io/guides/preprocessing_layers/

# %% [markdown]
# Data_loading >> https://keras.io/api/data_loading/image/
# 1. image_dataset_from_directory function = Generates a tf.data.Dataset from image files in a directory. (https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory)
# 2. load_img function = Loads an image into PIL format.
# 3. img_to_array function = Converts a PIL Image instance to a Numpy array.
# 4. save_img function = Saves an image stored as a Numpy array to a path or file object.

# %% [markdown]
# Keras models accept three types of inputs:
# - NumPy arrays
# - TensorFlow Dataset objects
# - Python generators

# %% [markdown]
# # 1.Setup

# %%
# List all NVIDIA GPUs as avaialble in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-1dee5bce-998f-418b-d057-2249ba9df605)

# %%
import sys
print(f"Python {sys.version}\n")

import numpy as np
print(f"Numpy {np.__version__}\n")

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
print(f"TensorFlow {tf.__version__}")
print(f"tf.keras.backend.image_data_format() = {tf.keras.backend.image_data_format()}")

# Count the number of GPUs as detected by tensorflow
gpus = tf.config.list_physical_devices('GPU')
print(f"TensorFlow detected {len(gpus)} GPU(s):")
for i,gpu in enumerate(gpus):
  print(f"...GPU No.{i} : Name = {gpu.name}, Type = {gpu.device_type}")
# Out:
# Python 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
#
# Numpy 1.21.6
#
# TensorFlow 2.9.2
# tf.keras.backend.image_data_format() = channels_last
# TensorFlow detected 1 GPU(s):
# ...GPU No.0 : Name = /physical_device:GPU:0, Type = GPU

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed
np.random.seed(1234)
tf.random.set_seed(1234)
# seed = np.random.randint(1000,10000)
seed = 1234

# %%
batch_size = 32
image_size = (224, 224) # Default of input_shape is 224x224x3 for ResNet152V2

# %% [markdown]
# # 2.Load data using a Keras utility

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Directory where the data is located. If labels is "inferred", it should contain subdirectories, each containing images for a class.
# Otherwise, the directory structure is ignored.
train_dir = "/content/gdrive/MyDrive/DADS_7202/dataset/train_ds"
test_dir = "/content/gdrive/MyDrive/DADS_7202/dataset/test_ds"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  seed=seed,
  validation_split=0.2,
  subset="training",
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 354 files belonging to 4 classes.
# Using 284 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  seed=seed,
  validation_split=0.2,
  subset="validation",
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 354 files belonging to 4 classes.
# Using 70 files for validation.

# %%
# Load test_dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 80 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['apple', 'huawei', 'oppo', 'samsung']

# %% [markdown]
# # 3.Load the pretrained model (only the feature extractor)

# %%
# https://keras.io/api/applications/resnet/#resnet152v2-function
img_w,img_h = 224,224 
vgg_extractor = tf.keras.applications.ResNet152V2(weights = "imagenet", include_top=True,input_shape = (img_w, img_h,3)) 

vgg_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels.h5
# 242745792/242745792 [==============================] - 5s 0us/step
# Model: "resnet152v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 28, 28, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 28, 28, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 28, 28, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
# ...
#  conv4_block35_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block35_1_relu[0][0]']
#  ng2D)
#
#  conv4_block35_2_conv (Conv2D)  (None, 14, 14, 256)  589824      ['conv4_block35_2_pad[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_out (Add)        (None, 14, 14, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 14, 14, 1024  4096       ['conv4_block35_out[0][0]']
#  Normalization)                 )
#
#  conv4_block36_preact_relu (Act  (None, 14, 14, 1024  0          ['conv4_block36_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block36_1_conv (Conv2D)  (None, 14, 14, 256)  262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 7, 7, 256)    589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 7, 7, 256)   1024        ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 7, 7, 256)   0           ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block35_out[0][0]']
#
#  conv4_block36_3_conv (Conv2D)  (None, 7, 7, 1024)   263168      ['conv4_block36_2_relu[0][0]']
#
#  conv4_block36_out (Add)        (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block36_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 60,380,648
# Trainable params: 60,236,904
# Non-trainable params: 143,744
# __________________________________________________________________________________________________

# %%
# All layer = False
vgg_extractor.trainable = False

# recheck layer.trainable

for i,layer in enumerate(vgg_extractor.layers):  
    print( f"Layer {i}: name = {layer.name} , trainable = {layer.trainable}" )
# Out:
# Layer 0: name = input_1 , trainable = False
# Layer 1: name = conv1_pad , trainable = False
# Layer 2: name = conv1_conv , trainable = False
# Layer 3: name = pool1_pad , trainable = False
# Layer 4: name = pool1_pool , trainable = False
# Layer 5: name = conv2_block1_preact_bn , trainable = False
# Layer 6: name = conv2_block1_preact_relu , trainable = False
# Layer 7: name = conv2_block1_1_conv , trainable = False
# Layer 8: name = conv2_block1_1_bn , trainable = False
# Layer 9: name = conv2_block1_1_relu , trainable = False
# Layer 10: name = conv2_block1_2_pad , trainable = False
# Layer 11: name = conv2_block1_2_conv , trainable = False
# Layer 12: name = conv2_block1_2_bn , trainable = False
# Layer 13: name = conv2_block1_2_relu , trainable = False
# Layer 14: name = conv2_block1_0_conv , trainable = False
# Layer 15: name = conv2_block1_3_conv , trainable = False
# Layer 16: name = conv2_block1_out , trainable = False
# Layer 17: name = conv2_block2_preact_bn , trainable = False
# Layer 18: name = conv2_block2_preact_relu , trainable = False
# Layer 19: name = conv2_block2_1_conv , trainable = False
# Layer 20: name = conv2_block2_1_bn , trainable = False
# Layer 21: name = conv2_block2_1_relu , trainable = False
# Layer 22: name = conv2_block2_2_pad , trainable = False
# Layer 23: name = conv2_block2_2_conv , trainable = False
# Layer 24: name = conv2_block2_2_bn , trainable = False
# Layer 25: name = conv2_block2_2_relu , trainable = False
# Layer 26: name = conv2_block2_3_conv , trainable = False
# Layer 27: name = conv2_block2_out , trainable = False
# Layer 28: name = conv2_block3_preact_bn , trainable = False
# Layer 29: name = conv2_block3_preact_relu , trainable = False
# Layer 30: name = conv2_block3_1_conv , trainable = False
# Layer 31: name = conv2_block3_1_bn , trainable = False
# Layer 32: name = conv2_block3_1_relu , trainable = False
# Layer 33: name = conv2_block3_2_pad , trainable = False
# Layer 34: name = conv2_block3_2_conv , trainable = False
# Layer 35: name = conv2_block3_2_bn , trainable = False
# Layer 36: name = conv2_block3_2_relu , trainable = False
# Layer 37: name = max_pooling2d , trainable = False
# Layer 38: name = conv2_block3_3_conv , trainable = False
# Layer 39: name = conv2_block3_out , trainable = False
# Layer 40: name = conv3_block1_preact_bn , trainable = False
# Layer 41: name = conv3_block1_preact_relu , trainable = False
# Layer 42: name = conv3_block1_1_conv , trainable = False
# Layer 43: name = conv3_block1_1_bn , trainable = False
# Layer 44: name = conv3_block1_1_relu , trainable = False
# Layer 45: name = conv3_block1_2_pad , trainable = False
# Layer 46: name = conv3_block1_2_conv , trainable = False
# Layer 47: name = conv3_block1_2_bn , trainable = False
# Layer 48: name = conv3_block1_2_relu , trainable = False
# Layer 49: name = conv3_block1_0_conv , trainable = False
# Layer 50: name = conv3_block1_3_conv , trainable = False
# Layer 51: name = conv3_block1_out , trainable = False
# Layer 52: name = conv3_block2_preact_bn , trainable = False
# Layer 53: name = conv3_block2_preact_relu , trainable = False
# Layer 54: name = conv3_block2_1_conv , trainable = False
# Layer 55: name = conv3_block2_1_bn , trainable = False
# Layer 56: name = conv3_block2_1_relu , trainable = False
# Layer 57: name = conv3_block2_2_pad , trainable = False
# Layer 58: name = conv3_block2_2_conv , trainable = False
# Layer 59: name = conv3_block2_2_bn , trainable = False
# Layer 60: name = conv3_block2_2_relu , trainable = False
# Layer 61: name = conv3_block2_3_conv , trainable = False
# Layer 62: name = conv3_block2_out , trainable = False
# Layer 63: name = conv3_block3_preact_bn , trainable = False
# Layer 64: name = conv3_block3_preact_relu , trainable = False
# Layer 65: name = conv3_block3_1_conv , trainable = False
# Layer 66: name = conv3_block3_1_bn , trainable = False
# Layer 67: name = conv3_block3_1_relu , trainable = False
# Layer 68: name = conv3_block3_2_pad , trainable = False
# Layer 69: name = conv3_block3_2_conv , trainable = False
# Layer 70: name = conv3_block3_2_bn , trainable = False
# Layer 71: name = conv3_block3_2_relu , trainable = False
# Layer 72: name = conv3_block3_3_conv , trainable = False
# Layer 73: name = conv3_block3_out , trainable = False
# Layer 74: name = conv3_block4_preact_bn , trainable = False
# Layer 75: name = conv3_block4_preact_relu , trainable = False
# Layer 76: name = conv3_block4_1_conv , trainable = False
# Layer 77: name = conv3_block4_1_bn , trainable = False
# Layer 78: name = conv3_block4_1_relu , trainable = False
# Layer 79: name = conv3_block4_2_pad , trainable = False
# Layer 80: name = conv3_block4_2_conv , trainable = False
# Layer 81: name = conv3_block4_2_bn , trainable = False
# Layer 82: name = conv3_block4_2_relu , trainable = False
# Layer 83: name = conv3_block4_3_conv , trainable = False
# Layer 84: name = conv3_block4_out , trainable = False
# Layer 85: name = conv3_block5_preact_bn , trainable = False
# Layer 86: name = conv3_block5_preact_relu , trainable = False
# Layer 87: name = conv3_block5_1_conv , trainable = False
# Layer 88: name = conv3_block5_1_bn , trainable = False
# Layer 89: name = conv3_block5_1_relu , trainable = False
# Layer 90: name = conv3_block5_2_pad , trainable = False
# Layer 91: name = conv3_block5_2_conv , trainable = False
# Layer 92: name = conv3_block5_2_bn , trainable = False
# Layer 93: name = conv3_block5_2_relu , trainable = False
# Layer 94: name = conv3_block5_3_conv , trainable = False
# Layer 95: name = conv3_block5_out , trainable = False
# Layer 96: name = conv3_block6_preact_bn , trainable = False
# Layer 97: name = conv3_block6_preact_relu , trainable = False
# Layer 98: name = conv3_block6_1_conv , trainable = False
# Layer 99: name = conv3_block6_1_bn , trainable = False
# Layer 100: name = conv3_block6_1_relu , trainable = False
# Layer 101: name = conv3_block6_2_pad , trainable = False
# Layer 102: name = conv3_block6_2_conv , trainable = False
# Layer 103: name = conv3_block6_2_bn , trainable = False
# Layer 104: name = conv3_block6_2_relu , trainable = False
# Layer 105: name = conv3_block6_3_conv , trainable = False
# Layer 106: name = conv3_block6_out , trainable = False
# Layer 107: name = conv3_block7_preact_bn , trainable = False
# Layer 108: name = conv3_block7_preact_relu , trainable = False
# Layer 109: name = conv3_block7_1_conv , trainable = False
# Layer 110: name = conv3_block7_1_bn , trainable = False
# Layer 111: name = conv3_block7_1_relu , trainable = False
# Layer 112: name = conv3_block7_2_pad , trainable = False
# Layer 113: name = conv3_block7_2_conv , trainable = False
# Layer 114: name = conv3_block7_2_bn , trainable = False
# Layer 115: name = conv3_block7_2_relu , trainable = False
# Layer 116: name = conv3_block7_3_conv , trainable = False
# Layer 117: name = conv3_block7_out , trainable = False
# Layer 118: name = conv3_block8_preact_bn , trainable = False
# Layer 119: name = conv3_block8_preact_relu , trainable = False
# Layer 120: name = conv3_block8_1_conv , trainable = False
# Layer 121: name = conv3_block8_1_bn , trainable = False
# Layer 122: name = conv3_block8_1_relu , trainable = False
# Layer 123: name = conv3_block8_2_pad , trainable = False
# Layer 124: name = conv3_block8_2_conv , trainable = False
# Layer 125: name = conv3_block8_2_bn , trainable = False
# Layer 126: name = conv3_block8_2_relu , trainable = False
# Layer 127: name = max_pooling2d_1 , trainable = False
# Layer 128: name = conv3_block8_3_conv , trainable = False
# Layer 129: name = conv3_block8_out , trainable = False
# Layer 130: name = conv4_block1_preact_bn , trainable = False
# Layer 131: name = conv4_block1_preact_relu , trainable = False
# Layer 132: name = conv4_block1_1_conv , trainable = False
# Layer 133: name = conv4_block1_1_bn , trainable = False
# Layer 134: name = conv4_block1_1_relu , trainable = False
# Layer 135: name = conv4_block1_2_pad , trainable = False
# Layer 136: name = conv4_block1_2_conv , trainable = False
# Layer 137: name = conv4_block1_2_bn , trainable = False
# Layer 138: name = conv4_block1_2_relu , trainable = False
# Layer 139: name = conv4_block1_0_conv , trainable = False
# Layer 140: name = conv4_block1_3_conv , trainable = False
# Layer 141: name = conv4_block1_out , trainable = False
# Layer 142: name = conv4_block2_preact_bn , trainable = False
# Layer 143: name = conv4_block2_preact_relu , trainable = False
# Layer 144: name = conv4_block2_1_conv , trainable = False
# Layer 145: name = conv4_block2_1_bn , trainable = False
# Layer 146: name = conv4_block2_1_relu , trainable = False
# Layer 147: name = conv4_block2_2_pad , trainable = False
# Layer 148: name = conv4_block2_2_conv , trainable = False
# Layer 149: name = conv4_block2_2_bn , trainable = False
# Layer 150: name = conv4_block2_2_relu , trainable = False
# Layer 151: name = conv4_block2_3_conv , trainable = False
# Layer 152: name = conv4_block2_out , trainable = False
# Layer 153: name = conv4_block3_preact_bn , trainable = False
# Layer 154: name = conv4_block3_preact_relu , trainable = False
# Layer 155: name = conv4_block3_1_conv , trainable = False
# Layer 156: name = conv4_block3_1_bn , trainable = False
# Layer 157: name = conv4_block3_1_relu , trainable = False
# Layer 158: name = conv4_block3_2_pad , trainable = False
# Layer 159: name = conv4_block3_2_conv , trainable = False
# Layer 160: name = conv4_block3_2_bn , trainable = False
# Layer 161: name = conv4_block3_2_relu , trainable = False
# Layer 162: name = conv4_block3_3_conv , trainable = False
# Layer 163: name = conv4_block3_out , trainable = False
# Layer 164: name = conv4_block4_preact_bn , trainable = False
# Layer 165: name = conv4_block4_preact_relu , trainable = False
# Layer 166: name = conv4_block4_1_conv , trainable = False
# Layer 167: name = conv4_block4_1_bn , trainable = False
# Layer 168: name = conv4_block4_1_relu , trainable = False
# Layer 169: name = conv4_block4_2_pad , trainable = False
# Layer 170: name = conv4_block4_2_conv , trainable = False
# Layer 171: name = conv4_block4_2_bn , trainable = False
# Layer 172: name = conv4_block4_2_relu , trainable = False
# Layer 173: name = conv4_block4_3_conv , trainable = False
# Layer 174: name = conv4_block4_out , trainable = False
# Layer 175: name = conv4_block5_preact_bn , trainable = False
# Layer 176: name = conv4_block5_preact_relu , trainable = False
# Layer 177: name = conv4_block5_1_conv , trainable = False
# Layer 178: name = conv4_block5_1_bn , trainable = False
# Layer 179: name = conv4_block5_1_relu , trainable = False
# Layer 180: name = conv4_block5_2_pad , trainable = False
# Layer 181: name = conv4_block5_2_conv , trainable = False
# Layer 182: name = conv4_block5_2_bn , trainable = False
# Layer 183: name = conv4_block5_2_relu , trainable = False
# Layer 184: name = conv4_block5_3_conv , trainable = False
# Layer 185: name = conv4_block5_out , trainable = False
# Layer 186: name = conv4_block6_preact_bn , trainable = False
# Layer 187: name = conv4_block6_preact_relu , trainable = False
# Layer 188: name = conv4_block6_1_conv , trainable = False
# Layer 189: name = conv4_block6_1_bn , trainable = False
# Layer 190: name = conv4_block6_1_relu , trainable = False
# Layer 191: name = conv4_block6_2_pad , trainable = False
# Layer 192: name = conv4_block6_2_conv , trainable = False
# Layer 193: name = conv4_block6_2_bn , trainable = False
# Layer 194: name = conv4_block6_2_relu , trainable = False
# Layer 195: name = conv4_block6_3_conv , trainable = False
# Layer 196: name = conv4_block6_out , trainable = False
# Layer 197: name = conv4_block7_preact_bn , trainable = False
# Layer 198: name = conv4_block7_preact_relu , trainable = False
# Layer 199: name = conv4_block7_1_conv , trainable = False
# Layer 200: name = conv4_block7_1_bn , trainable = False
# Layer 201: name = conv4_block7_1_relu , trainable = False
# Layer 202: name = conv4_block7_2_pad , trainable = False
# Layer 203: name = conv4_block7_2_conv , trainable = False
# Layer 204: name = conv4_block7_2_bn , trainable = False
# Layer 205: name = conv4_block7_2_relu , trainable = False
# Layer 206: name = conv4_block7_3_conv , trainable = False
# Layer 207: name = conv4_block7_out , trainable = False
# Layer 208: name = conv4_block8_preact_bn , trainable = False
# Layer 209: name = conv4_block8_preact_relu , trainable = False
# Layer 210: name = conv4_block8_1_conv , trainable = False
# Layer 211: name = conv4_block8_1_bn , trainable = False
# Layer 212: name = conv4_block8_1_relu , trainable = False
# Layer 213: name = conv4_block8_2_pad , trainable = False
# Layer 214: name = conv4_block8_2_conv , trainable = False
# Layer 215: name = conv4_block8_2_bn , trainable = False
# Layer 216: name = conv4_block8_2_relu , trainable = False
# Layer 217: name = conv4_block8_3_conv , trainable = False
# Layer 218: name = conv4_block8_out , trainable = False
# Layer 219: name = conv4_block9_preact_bn , trainable = False
# Layer 220: name = conv4_block9_preact_relu , trainable = False
# Layer 221: name = conv4_block9_1_conv , trainable = False
# Layer 222: name = conv4_block9_1_bn , trainable = False
# Layer 223: name = conv4_block9_1_relu , trainable = False
# Layer 224: name = conv4_block9_2_pad , trainable = False
# Layer 225: name = conv4_block9_2_conv , trainable = False
# Layer 226: name = conv4_block9_2_bn , trainable = False
# Layer 227: name = conv4_block9_2_relu , trainable = False
# Layer 228: name = conv4_block9_3_conv , trainable = False
# Layer 229: name = conv4_block9_out , trainable = False
# Layer 230: name = conv4_block10_preact_bn , trainable = False
# Layer 231: name = conv4_block10_preact_relu , trainable = False
# Layer 232: name = conv4_block10_1_conv , trainable = False
# Layer 233: name = conv4_block10_1_bn , trainable = False
# Layer 234: name = conv4_block10_1_relu , trainable = False
# Layer 235: name = conv4_block10_2_pad , trainable = False
# Layer 236: name = conv4_block10_2_conv , trainable = False
# Layer 237: name = conv4_block10_2_bn , trainable = False
# Layer 238: name = conv4_block10_2_relu , trainable = False
# Layer 239: name = conv4_block10_3_conv , trainable = False
# Layer 240: name = conv4_block10_out , trainable = False
# Layer 241: name = conv4_block11_preact_bn , trainable = False
# Layer 242: name = conv4_block11_preact_relu , trainable = False
# Layer 243: name = conv4_block11_1_conv , trainable = False
# Layer 244: name = conv4_block11_1_bn , trainable = False
# Layer 245: name = conv4_block11_1_relu , trainable = False
# Layer 246: name = conv4_block11_2_pad , trainable = False
# Layer 247: name = conv4_block11_2_conv , trainable = False
# Layer 248: name = conv4_block11_2_bn , trainable = False
# Layer 249: name = conv4_block11_2_relu , trainable = False
# Layer 250: name = conv4_block11_3_conv , trainable = False
# Layer 251: name = conv4_block11_out , trainable = False
# Layer 252: name = conv4_block12_preact_bn , trainable = False
# Layer 253: name = conv4_block12_preact_relu , trainable = False
# Layer 254: name = conv4_block12_1_conv , trainable = False
# Layer 255: name = conv4_block12_1_bn , trainable = False
# Layer 256: name = conv4_block12_1_relu , trainable = False
# Layer 257: name = conv4_block12_2_pad , trainable = False
# Layer 258: name = conv4_block12_2_conv , trainable = False
# Layer 259: name = conv4_block12_2_bn , trainable = False
# Layer 260: name = conv4_block12_2_relu , trainable = False
# Layer 261: name = conv4_block12_3_conv , trainable = False
# Layer 262: name = conv4_block12_out , trainable = False
# Layer 263: name = conv4_block13_preact_bn , trainable = False
# Layer 264: name = conv4_block13_preact_relu , trainable = False
# Layer 265: name = conv4_block13_1_conv , trainable = False
# Layer 266: name = conv4_block13_1_bn , trainable = False
# Layer 267: name = conv4_block13_1_relu , trainable = False
# Layer 268: name = conv4_block13_2_pad , trainable = False
# Layer 269: name = conv4_block13_2_conv , trainable = False
# Layer 270: name = conv4_block13_2_bn , trainable = False
# Layer 271: name = conv4_block13_2_relu , trainable = False
# Layer 272: name = conv4_block13_3_conv , trainable = False
# Layer 273: name = conv4_block13_out , trainable = False
# Layer 274: name = conv4_block14_preact_bn , trainable = False
# Layer 275: name = conv4_block14_preact_relu , trainable = False
# Layer 276: name = conv4_block14_1_conv , trainable = False
# Layer 277: name = conv4_block14_1_bn , trainable = False
# Layer 278: name = conv4_block14_1_relu , trainable = False
# Layer 279: name = conv4_block14_2_pad , trainable = False
# Layer 280: name = conv4_block14_2_conv , trainable = False
# Layer 281: name = conv4_block14_2_bn , trainable = False
# Layer 282: name = conv4_block14_2_relu , trainable = False
# Layer 283: name = conv4_block14_3_conv , trainable = False
# Layer 284: name = conv4_block14_out , trainable = False
# Layer 285: name = conv4_block15_preact_bn , trainable = False
# Layer 286: name = conv4_block15_preact_relu , trainable = False
# Layer 287: name = conv4_block15_1_conv , trainable = False
# Layer 288: name = conv4_block15_1_bn , trainable = False
# Layer 289: name = conv4_block15_1_relu , trainable = False
# Layer 290: name = conv4_block15_2_pad , trainable = False
# Layer 291: name = conv4_block15_2_conv , trainable = False
# Layer 292: name = conv4_block15_2_bn , trainable = False
# Layer 293: name = conv4_block15_2_relu , trainable = False
# Layer 294: name = conv4_block15_3_conv , trainable = False
# Layer 295: name = conv4_block15_out , trainable = False
# Layer 296: name = conv4_block16_preact_bn , trainable = False
# Layer 297: name = conv4_block16_preact_relu , trainable = False
# Layer 298: name = conv4_block16_1_conv , trainable = False
# Layer 299: name = conv4_block16_1_bn , trainable = False
# Layer 300: name = conv4_block16_1_relu , trainable = False
# Layer 301: name = conv4_block16_2_pad , trainable = False
# Layer 302: name = conv4_block16_2_conv , trainable = False
# Layer 303: name = conv4_block16_2_bn , trainable = False
# Layer 304: name = conv4_block16_2_relu , trainable = False
# Layer 305: name = conv4_block16_3_conv , trainable = False
# Layer 306: name = conv4_block16_out , trainable = False
# Layer 307: name = conv4_block17_preact_bn , trainable = False
# Layer 308: name = conv4_block17_preact_relu , trainable = False
# Layer 309: name = conv4_block17_1_conv , trainable = False
# Layer 310: name = conv4_block17_1_bn , trainable = False
# Layer 311: name = conv4_block17_1_relu , trainable = False
# Layer 312: name = conv4_block17_2_pad , trainable = False
# Layer 313: name = conv4_block17_2_conv , trainable = False
# Layer 314: name = conv4_block17_2_bn , trainable = False
# Layer 315: name = conv4_block17_2_relu , trainable = False
# Layer 316: name = conv4_block17_3_conv , trainable = False
# Layer 317: name = conv4_block17_out , trainable = False
# Layer 318: name = conv4_block18_preact_bn , trainable = False
# Layer 319: name = conv4_block18_preact_relu , trainable = False
# Layer 320: name = conv4_block18_1_conv , trainable = False
# Layer 321: name = conv4_block18_1_bn , trainable = False
# Layer 322: name = conv4_block18_1_relu , trainable = False
# Layer 323: name = conv4_block18_2_pad , trainable = False
# Layer 324: name = conv4_block18_2_conv , trainable = False
# Layer 325: name = conv4_block18_2_bn , trainable = False
# Layer 326: name = conv4_block18_2_relu , trainable = False
# Layer 327: name = conv4_block18_3_conv , trainable = False
# Layer 328: name = conv4_block18_out , trainable = False
# Layer 329: name = conv4_block19_preact_bn , trainable = False
# Layer 330: name = conv4_block19_preact_relu , trainable = False
# Layer 331: name = conv4_block19_1_conv , trainable = False
# Layer 332: name = conv4_block19_1_bn , trainable = False
# Layer 333: name = conv4_block19_1_relu , trainable = False
# Layer 334: name = conv4_block19_2_pad , trainable = False
# Layer 335: name = conv4_block19_2_conv , trainable = False
# Layer 336: name = conv4_block19_2_bn , trainable = False
# Layer 337: name = conv4_block19_2_relu , trainable = False
# Layer 338: name = conv4_block19_3_conv , trainable = False
# Layer 339: name = conv4_block19_out , trainable = False
# Layer 340: name = conv4_block20_preact_bn , trainable = False
# Layer 341: name = conv4_block20_preact_relu , trainable = False
# Layer 342: name = conv4_block20_1_conv , trainable = False
# Layer 343: name = conv4_block20_1_bn , trainable = False
# Layer 344: name = conv4_block20_1_relu , trainable = False
# Layer 345: name = conv4_block20_2_pad , trainable = False
# Layer 346: name = conv4_block20_2_conv , trainable = False
# Layer 347: name = conv4_block20_2_bn , trainable = False
# Layer 348: name = conv4_block20_2_relu , trainable = False
# Layer 349: name = conv4_block20_3_conv , trainable = False
# Layer 350: name = conv4_block20_out , trainable = False
# Layer 351: name = conv4_block21_preact_bn , trainable = False
# Layer 352: name = conv4_block21_preact_relu , trainable = False
# Layer 353: name = conv4_block21_1_conv , trainable = False
# Layer 354: name = conv4_block21_1_bn , trainable = False
# Layer 355: name = conv4_block21_1_relu , trainable = False
# Layer 356: name = conv4_block21_2_pad , trainable = False
# Layer 357: name = conv4_block21_2_conv , trainable = False
# Layer 358: name = conv4_block21_2_bn , trainable = False
# Layer 359: name = conv4_block21_2_relu , trainable = False
# Layer 360: name = conv4_block21_3_conv , trainable = False
# Layer 361: name = conv4_block21_out , trainable = False
# Layer 362: name = conv4_block22_preact_bn , trainable = False
# Layer 363: name = conv4_block22_preact_relu , trainable = False
# Layer 364: name = conv4_block22_1_conv , trainable = False
# Layer 365: name = conv4_block22_1_bn , trainable = False
# Layer 366: name = conv4_block22_1_relu , trainable = False
# Layer 367: name = conv4_block22_2_pad , trainable = False
# Layer 368: name = conv4_block22_2_conv , trainable = False
# Layer 369: name = conv4_block22_2_bn , trainable = False
# Layer 370: name = conv4_block22_2_relu , trainable = False
# Layer 371: name = conv4_block22_3_conv , trainable = False
# Layer 372: name = conv4_block22_out , trainable = False
# Layer 373: name = conv4_block23_preact_bn , trainable = False
# Layer 374: name = conv4_block23_preact_relu , trainable = False
# Layer 375: name = conv4_block23_1_conv , trainable = False
# Layer 376: name = conv4_block23_1_bn , trainable = False
# Layer 377: name = conv4_block23_1_relu , trainable = False
# Layer 378: name = conv4_block23_2_pad , trainable = False
# Layer 379: name = conv4_block23_2_conv , trainable = False
# Layer 380: name = conv4_block23_2_bn , trainable = False
# Layer 381: name = conv4_block23_2_relu , trainable = False
# Layer 382: name = conv4_block23_3_conv , trainable = False
# Layer 383: name = conv4_block23_out , trainable = False
# Layer 384: name = conv4_block24_preact_bn , trainable = False
# Layer 385: name = conv4_block24_preact_relu , trainable = False
# Layer 386: name = conv4_block24_1_conv , trainable = False
# Layer 387: name = conv4_block24_1_bn , trainable = False
# Layer 388: name = conv4_block24_1_relu , trainable = False
# Layer 389: name = conv4_block24_2_pad , trainable = False
# Layer 390: name = conv4_block24_2_conv , trainable = False
# Layer 391: name = conv4_block24_2_bn , trainable = False
# Layer 392: name = conv4_block24_2_relu , trainable = False
# Layer 393: name = conv4_block24_3_conv , trainable = False
# Layer 394: name = conv4_block24_out , trainable = False
# Layer 395: name = conv4_block25_preact_bn , trainable = False
# Layer 396: name = conv4_block25_preact_relu , trainable = False
# Layer 397: name = conv4_block25_1_conv , trainable = False
# Layer 398: name = conv4_block25_1_bn , trainable = False
# Layer 399: name = conv4_block25_1_relu , trainable = False
# Layer 400: name = conv4_block25_2_pad , trainable = False
# Layer 401: name = conv4_block25_2_conv , trainable = False
# Layer 402: name = conv4_block25_2_bn , trainable = False
# Layer 403: name = conv4_block25_2_relu , trainable = False
# Layer 404: name = conv4_block25_3_conv , trainable = False
# Layer 405: name = conv4_block25_out , trainable = False
# Layer 406: name = conv4_block26_preact_bn , trainable = False
# Layer 407: name = conv4_block26_preact_relu , trainable = False
# Layer 408: name = conv4_block26_1_conv , trainable = False
# Layer 409: name = conv4_block26_1_bn , trainable = False
# Layer 410: name = conv4_block26_1_relu , trainable = False
# Layer 411: name = conv4_block26_2_pad , trainable = False
# Layer 412: name = conv4_block26_2_conv , trainable = False
# Layer 413: name = conv4_block26_2_bn , trainable = False
# Layer 414: name = conv4_block26_2_relu , trainable = False
# Layer 415: name = conv4_block26_3_conv , trainable = False
# Layer 416: name = conv4_block26_out , trainable = False
# Layer 417: name = conv4_block27_preact_bn , trainable = False
# Layer 418: name = conv4_block27_preact_relu , trainable = False
# Layer 419: name = conv4_block27_1_conv , trainable = False
# Layer 420: name = conv4_block27_1_bn , trainable = False
# Layer 421: name = conv4_block27_1_relu , trainable = False
# Layer 422: name = conv4_block27_2_pad , trainable = False
# Layer 423: name = conv4_block27_2_conv , trainable = False
# Layer 424: name = conv4_block27_2_bn , trainable = False
# Layer 425: name = conv4_block27_2_relu , trainable = False
# Layer 426: name = conv4_block27_3_conv , trainable = False
# Layer 427: name = conv4_block27_out , trainable = False
# Layer 428: name = conv4_block28_preact_bn , trainable = False
# Layer 429: name = conv4_block28_preact_relu , trainable = False
# Layer 430: name = conv4_block28_1_conv , trainable = False
# Layer 431: name = conv4_block28_1_bn , trainable = False
# Layer 432: name = conv4_block28_1_relu , trainable = False
# Layer 433: name = conv4_block28_2_pad , trainable = False
# Layer 434: name = conv4_block28_2_conv , trainable = False
# Layer 435: name = conv4_block28_2_bn , trainable = False
# Layer 436: name = conv4_block28_2_relu , trainable = False
# Layer 437: name = conv4_block28_3_conv , trainable = False
# Layer 438: name = conv4_block28_out , trainable = False
# Layer 439: name = conv4_block29_preact_bn , trainable = False
# Layer 440: name = conv4_block29_preact_relu , trainable = False
# Layer 441: name = conv4_block29_1_conv , trainable = False
# Layer 442: name = conv4_block29_1_bn , trainable = False
# Layer 443: name = conv4_block29_1_relu , trainable = False
# Layer 444: name = conv4_block29_2_pad , trainable = False
# Layer 445: name = conv4_block29_2_conv , trainable = False
# Layer 446: name = conv4_block29_2_bn , trainable = False
# Layer 447: name = conv4_block29_2_relu , trainable = False
# Layer 448: name = conv4_block29_3_conv , trainable = False
# Layer 449: name = conv4_block29_out , trainable = False
# Layer 450: name = conv4_block30_preact_bn , trainable = False
# Layer 451: name = conv4_block30_preact_relu , trainable = False
# Layer 452: name = conv4_block30_1_conv , trainable = False
# Layer 453: name = conv4_block30_1_bn , trainable = False
# Layer 454: name = conv4_block30_1_relu , trainable = False
# Layer 455: name = conv4_block30_2_pad , trainable = False
# Layer 456: name = conv4_block30_2_conv , trainable = False
# Layer 457: name = conv4_block30_2_bn , trainable = False
# Layer 458: name = conv4_block30_2_relu , trainable = False
# Layer 459: name = conv4_block30_3_conv , trainable = False
# Layer 460: name = conv4_block30_out , trainable = False
# Layer 461: name = conv4_block31_preact_bn , trainable = False
# Layer 462: name = conv4_block31_preact_relu , trainable = False
# Layer 463: name = conv4_block31_1_conv , trainable = False
# Layer 464: name = conv4_block31_1_bn , trainable = False
# Layer 465: name = conv4_block31_1_relu , trainable = False
# Layer 466: name = conv4_block31_2_pad , trainable = False
# Layer 467: name = conv4_block31_2_conv , trainable = False
# Layer 468: name = conv4_block31_2_bn , trainable = False
# Layer 469: name = conv4_block31_2_relu , trainable = False
# Layer 470: name = conv4_block31_3_conv , trainable = False
# Layer 471: name = conv4_block31_out , trainable = False
# Layer 472: name = conv4_block32_preact_bn , trainable = False
# Layer 473: name = conv4_block32_preact_relu , trainable = False
# Layer 474: name = conv4_block32_1_conv , trainable = False
# Layer 475: name = conv4_block32_1_bn , trainable = False
# Layer 476: name = conv4_block32_1_relu , trainable = False
# Layer 477: name = conv4_block32_2_pad , trainable = False
# Layer 478: name = conv4_block32_2_conv , trainable = False
# Layer 479: name = conv4_block32_2_bn , trainable = False
# Layer 480: name = conv4_block32_2_relu , trainable = False
# Layer 481: name = conv4_block32_3_conv , trainable = False
# Layer 482: name = conv4_block32_out , trainable = False
# Layer 483: name = conv4_block33_preact_bn , trainable = False
# Layer 484: name = conv4_block33_preact_relu , trainable = False
# Layer 485: name = conv4_block33_1_conv , trainable = False
# Layer 486: name = conv4_block33_1_bn , trainable = False
# Layer 487: name = conv4_block33_1_relu , trainable = False
# Layer 488: name = conv4_block33_2_pad , trainable = False
# Layer 489: name = conv4_block33_2_conv , trainable = False
# Layer 490: name = conv4_block33_2_bn , trainable = False
# Layer 491: name = conv4_block33_2_relu , trainable = False
# Layer 492: name = conv4_block33_3_conv , trainable = False
# Layer 493: name = conv4_block33_out , trainable = False
# Layer 494: name = conv4_block34_preact_bn , trainable = False
# Layer 495: name = conv4_block34_preact_relu , trainable = False
# Layer 496: name = conv4_block34_1_conv , trainable = False
# Layer 497: name = conv4_block34_1_bn , trainable = False
# Layer 498: name = conv4_block34_1_relu , trainable = False
# Layer 499: name = conv4_block34_2_pad , trainable = False
# Layer 500: name = conv4_block34_2_conv , trainable = False
# Layer 501: name = conv4_block34_2_bn , trainable = False
# Layer 502: name = conv4_block34_2_relu , trainable = False
# Layer 503: name = conv4_block34_3_conv , trainable = False
# Layer 504: name = conv4_block34_out , trainable = False
# Layer 505: name = conv4_block35_preact_bn , trainable = False
# Layer 506: name = conv4_block35_preact_relu , trainable = False
# Layer 507: name = conv4_block35_1_conv , trainable = False
# Layer 508: name = conv4_block35_1_bn , trainable = False
# Layer 509: name = conv4_block35_1_relu , trainable = False
# Layer 510: name = conv4_block35_2_pad , trainable = False
# Layer 511: name = conv4_block35_2_conv , trainable = False
# Layer 512: name = conv4_block35_2_bn , trainable = False
# Layer 513: name = conv4_block35_2_relu , trainable = False
# Layer 514: name = conv4_block35_3_conv , trainable = False
# Layer 515: name = conv4_block35_out , trainable = False
# Layer 516: name = conv4_block36_preact_bn , trainable = False
# Layer 517: name = conv4_block36_preact_relu , trainable = False
# Layer 518: name = conv4_block36_1_conv , trainable = False
# Layer 519: name = conv4_block36_1_bn , trainable = False
# Layer 520: name = conv4_block36_1_relu , trainable = False
# Layer 521: name = conv4_block36_2_pad , trainable = False
# Layer 522: name = conv4_block36_2_conv , trainable = False
# Layer 523: name = conv4_block36_2_bn , trainable = False
# Layer 524: name = conv4_block36_2_relu , trainable = False
# Layer 525: name = max_pooling2d_2 , trainable = False
# Layer 526: name = conv4_block36_3_conv , trainable = False
# Layer 527: name = conv4_block36_out , trainable = False
# Layer 528: name = conv5_block1_preact_bn , trainable = False
# Layer 529: name = conv5_block1_preact_relu , trainable = False
# Layer 530: name = conv5_block1_1_conv , trainable = False
# Layer 531: name = conv5_block1_1_bn , trainable = False
# Layer 532: name = conv5_block1_1_relu , trainable = False
# Layer 533: name = conv5_block1_2_pad , trainable = False
# Layer 534: name = conv5_block1_2_conv , trainable = False
# Layer 535: name = conv5_block1_2_bn , trainable = False
# Layer 536: name = conv5_block1_2_relu , trainable = False
# Layer 537: name = conv5_block1_0_conv , trainable = False
# Layer 538: name = conv5_block1_3_conv , trainable = False
# Layer 539: name = conv5_block1_out , trainable = False
# Layer 540: name = conv5_block2_preact_bn , trainable = False
# Layer 541: name = conv5_block2_preact_relu , trainable = False
# Layer 542: name = conv5_block2_1_conv , trainable = False
# Layer 543: name = conv5_block2_1_bn , trainable = False
# Layer 544: name = conv5_block2_1_relu , trainable = False
# Layer 545: name = conv5_block2_2_pad , trainable = False
# Layer 546: name = conv5_block2_2_conv , trainable = False
# Layer 547: name = conv5_block2_2_bn , trainable = False
# Layer 548: name = conv5_block2_2_relu , trainable = False
# Layer 549: name = conv5_block2_3_conv , trainable = False
# Layer 550: name = conv5_block2_out , trainable = False
# Layer 551: name = conv5_block3_preact_bn , trainable = False
# Layer 552: name = conv5_block3_preact_relu , trainable = False
# Layer 553: name = conv5_block3_1_conv , trainable = False
# Layer 554: name = conv5_block3_1_bn , trainable = False
# Layer 555: name = conv5_block3_1_relu , trainable = False
# Layer 556: name = conv5_block3_2_pad , trainable = False
# Layer 557: name = conv5_block3_2_conv , trainable = False
# Layer 558: name = conv5_block3_2_bn , trainable = False
# Layer 559: name = conv5_block3_2_relu , trainable = False
# Layer 560: name = conv5_block3_3_conv , trainable = False
# Layer 561: name = conv5_block3_out , trainable = False
# Layer 562: name = post_bn , trainable = False
# Layer 563: name = post_relu , trainable = False
# Layer 564: name = avg_pool , trainable = False
# Layer 565: name = predictions , trainable = False

# %%
tf.keras.utils.plot_model(vgg_extractor, to_file='ResNet152V2_sequential.png', show_shapes=True, show_dtype=True, show_layer_names=False, dpi=150)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.339196 to fit

# %% [markdown]
# # 4.Compile and train the model

# %%
# %pwd
# Out:
# '/content'

# %%
initial_learning_rate = 0.0001 # Defaults to 0.001

vgg_extractor.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["acc"]
    )

# %%
# %cd "/content/gdrive/MyDrive/DADS_7202/vgg_model/preprocess"

# %%
checkpoint_filepath = "bestmodel_epoch{epoch:02d}_valloss{val_loss:.2f}.hdf5"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                               save_weights_only=False, 
                                                               monitor='val_acc', 
                                                               mode='max',
                                                               save_best_only=True)

# %%
# %%time
history = vgg_extractor.fit(train_ds,
                    batch_size = None,
                    epochs=10, verbose=1,
                    validation_data=val_ds,
                    callbacks=[model_checkpoint_callback]
                    )
# Out:
# Epoch 1/10
# 9/9 [==============================] - 112s 3s/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7070 - val_acc: 0.0000e+00
# Epoch 2/10
# 9/9 [==============================] - 4s 306ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 3/10
# 9/9 [==============================] - 4s 305ms/step - loss: 2830.3682 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 4/10
# 9/9 [==============================] - 4s 307ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 5/10
# 9/9 [==============================] - 4s 308ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 6/10
# 9/9 [==============================] - 4s 309ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 7/10
# 9/9 [==============================] - 4s 310ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 8/10
# 9/9 [==============================] - 4s 307ms/step - loss: 2830.3679 - acc: 0.0000e+00 - val_loss: 2836.7073 - val_acc: 0.0000e+00
# Epoch 9/10
# 9/9 [==============================] - 4s 312ms/step - loss: 2830.3682 - acc: 0.0000e+00 - val_loss: 2836.7070 - val_acc: 0.0000e+00
# Epoch 10/10
# 9/9 [==============================] - 4s 313ms/step - loss: 2830.3682 - acc: 0.0000e+00 - val_loss: 2836.7070 - val_acc: 0.0000e+00
# CPU times: user 36.4 s, sys: 3.58 s, total: 40 s
# Wall time: 3min 10s

# %%
# %ls
# Out:
# bestmodel_epoch01_valloss2836.71.hdf5  ResNet152V2_sequential.png
# gdrive/                                sample_data/

# %%
# Check the keys in 'history'
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# Summarize history for accuracy
plt.figure(figsize=(15,5))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Train accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.show()

# Summarize history for loss
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Train loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# # 5.Evaluate the model

# %%
# Evaluate the model
results = vgg_extractor.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 25s 518ms/step - loss: 2508.2310 - acc: 0.0000e+00

# %%
print( f"Test results from last model:{vgg_extractor.metrics_names}: {results}\n" )
# Out:
# Test results from last model:['loss', 'acc']: [2508.23095703125, 0.0]

# %% [markdown]
# #6.Inference

# %%
test_ds_u = test_ds.unbatch()

lst_x = []
lst_y = []
for batch_images, batch_labels in test_ds_u :
  A = tf.keras.applications.vgg16.preprocess_input(batch_images)
  B = batch_labels
  lst_x.append(A)
  lst_y.append(B)

x_test = tf.stack(lst_x)
y_test = tf.stack(lst_y)

# %%
x_test.shape
# Out:
# TensorShape([80, 224, 224, 3])

# %%
x_test[0].dtype
# Out:
# tf.float32

# %%
x = tf.keras.applications.vgg16.preprocess_input(x_test)

# %%
# Use the model to predict this image
pred = vgg_extractor.predict(x)  #reshape ก็ได้ เพื่อบอก Batch size
# Out:
# 3/3 [==============================] - 3s 243ms/step

# %%
pred.shape
# Out:
# (80, 1000)

# %%
for j in range(10):
  predictions = tf.keras.applications.vgg16.decode_predictions(pred, top=5)[j]
  print("Pic", j+1 , "Class: ", class_names[y_test[j]])
  for i, prediction in enumerate(predictions):
    print( f"\tRank {i+1}: {prediction[1],prediction[2]}")
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Pic 1 Class:  apple
# 	Rank 1: ('binoculars', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('lycaenid', 0.0)
# 	Rank 4: ('sorrel', 0.0)
# 	Rank 5: ('guinea_pig', 0.0)
# Pic 2 Class:  huawei
# 	Rank 1: ('binoculars', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('lycaenid', 0.0)
# 	Rank 4: ('sorrel', 0.0)
# 	Rank 5: ('guinea_pig', 0.0)
# Pic 3 Class:  apple
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)
# Pic 4 Class:  oppo
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)
# Pic 5 Class:  oppo
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)
# Pic 6 Class:  apple
# 	Rank 1: ('binoculars', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('lycaenid', 0.0)
# 	Rank 4: ('sorrel', 0.0)
# 	Rank 5: ('guinea_pig', 0.0)
# Pic 7 Class:  samsung
# 	Rank 1: ('table_lamp', 1.0)
# 	Rank 2: ('joystick', 4.994728e-23)
# 	Rank 3: ('binoculars', 4.018113e-29)
# 	Rank 4: ('toilet_tissue', 0.0)
# 	Rank 5: ('hamster', 0.0)
# Pic 8 Class:  oppo
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)
# Pic 9 Class:  oppo
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)
# Pic 10 Class:  samsung
# 	Rank 1: ('joystick', 1.0)
# 	Rank 2: ('toilet_tissue', 0.0)
# 	Rank 3: ('starfish', 0.0)
# 	Rank 4: ('zebra', 0.0)
# 	Rank 5: ('sorrel', 0.0)

# %%
plt.figure(figsize=(20, 20))

for i in range(10):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(x_test[i].numpy().astype("uint8"))
  plt.title( class_names[y_test[i]] )
  plt.axis("off")

# %% [markdown]
# # 7.Classification 10 vs Input 4

# %%
# Retrieve a batch of images from the test set
image_batch,label_batch  = test_ds.as_numpy_iterator().next()
predictions = vgg_extractor.predict_on_batch(image_batch) # Returns predictions for a single batch of samples.

# %%
print (type(image_batch),", dtype=",image_batch.dtype,", shape=",image_batch.shape)
print (type(label_batch ),", dtype=",label_batch .dtype,", shape=",label_batch .shape)
# Out:
# <class 'numpy.ndarray'> , dtype= float32 , shape= (32, 224, 224, 3)
# <class 'numpy.ndarray'> , dtype= int32 , shape= (32,)

# %%
for i in range(10):
  print("No.", i, 'Labels:', class_names[label_batch[i]], 'Predictions:', class_names[np.argmax(predictions[i])])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-ca78391152f6> in <module>
#       1 for i in range(10):
# ----> 2   print("No.", i, 'Labels:', class_names[label_batch[i]], 'Predictions:', class_names[np.argmax(predictions[i])])
#
# IndexError: list index out of range

# %%
plt.figure(figsize=(20, 20))

for i in range(20):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title( class_names[label_batch[i]] + "-" +class_names[np.argmax(predictions[i])] )  # y_test y_pred
  plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-8c56d58bad5e> in <module>
#       4   ax = plt.subplot(5, 5, i + 1)
#       5   plt.imshow(image_batch[i].astype("uint8"))
# ----> 6   plt.title( class_names[label_batch[i]] + "-" +class_names[np.argmax(predictions[i])] )  # y_test y_pred
#       7   plt.axis("off")
#
# IndexError: list index out of range

# %% [markdown]
# # 8.Download model

# %%
# !cp bestmodel_epoch01_valloss2836.71.hdf5 /content/gdrive/MyDrive
