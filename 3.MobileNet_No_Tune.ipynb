# %% [markdown]
# # Reference

# %% [markdown]
# Tensorflow
# 1. https://www.tensorflow.org/tutorials/images/classification
# 2. https://www.tensorflow.org/tutorials/load_data/images
# 3. https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
# 4. https://www.tensorflow.org/api_docs/python/tf/keras/Model#predict

# %% [markdown]
# Keras (https://keras.io/api/)
# 1. https://keras.io/examples/vision/image_classification_from_scratch/
# 2. https://keras.io/guides/preprocessing_layers/

# %% [markdown]
# Data_loading >> https://keras.io/api/data_loading/image/
# 1. image_dataset_from_directory function = Generates a tf.data.Dataset from image files in a directory. (https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory)
# 2. load_img function = Loads an image into PIL format.
# 3. img_to_array function = Converts a PIL Image instance to a Numpy array.
# 4. save_img function = Saves an image stored as a Numpy array to a path or file object.

# %% [markdown]
# Keras models accept three types of inputs:
# - NumPy arrays
# - TensorFlow Dataset objects
# - Python generators

# %% [markdown]
# # 1.Setup

# %%
# List all NVIDIA GPUs as avaialble in this computer (or Colab's session)
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-b750da64-a0fa-50a9-eebd-8fa0b15fe2f9)

# %%
import sys
print(f"Python {sys.version}\n")

import numpy as np
print(f"Numpy {np.__version__}\n")

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
print(f"TensorFlow {tf.__version__}")
print(f"tf.keras.backend.image_data_format() = {tf.keras.backend.image_data_format()}")

# Count the number of GPUs as detected by tensorflow
gpus = tf.config.list_physical_devices('GPU')
print(f"TensorFlow detected {len(gpus)} GPU(s):")
for i,gpu in enumerate(gpus):
  print(f"...GPU No.{i} : Name = {gpu.name}, Type = {gpu.device_type}")
# Out:
# Python 3.7.15 (default, Oct 12 2022, 19:14:55)
# [GCC 7.5.0]
#
# Numpy 1.21.6
#
# TensorFlow 2.9.2
# tf.keras.backend.image_data_format() = channels_last
# TensorFlow detected 1 GPU(s):
# ...GPU No.0 : Name = /physical_device:GPU:0, Type = GPU

# %%
# Set fixed seeding values for reproducability during experiments
# Skip this cell if random initialization (with varied results) is needed
np.random.seed(1234)
tf.random.set_seed(1234)
# seed = np.random.randint(1000,10000)
seed = 1234

# %%
batch_size = 32
image_size = (224, 224) # Default of input_shape is 224x224x3 for MobileNet

# %% [markdown]
# # 2.Load data using a Keras utility

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Directory where the data is located. If labels is "inferred", it should contain subdirectories, each containing images for a class.
# Otherwise, the directory structure is ignored.
train_dir = "/content/gdrive/MyDrive/DADS_7202/dataset/train_ds"
test_dir = "/content/gdrive/MyDrive/DADS_7202/dataset/test_ds"

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  seed=seed,
  validation_split=0.2,
  subset="training",
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 354 files belonging to 4 classes.
# Using 284 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  seed=seed,
  validation_split=0.2,
  subset="validation",
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 354 files belonging to 4 classes.
# Using 70 files for validation.

# %%
# Load test_dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir,
  labels='inferred',
  label_mode='int', # if label_mode is int, the labels are an int32 tensor of shape (batch_size,)
  class_names=None, # otherwise alphanumerical order is used
  color_mode='rgb',
  batch_size=batch_size,
  image_size=image_size,
  shuffle=True,
  interpolation='bilinear',
  follow_links=False,
  crop_to_aspect_ratio=False
  )
# Out:
# Found 80 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['apple', 'huawei', 'oppo', 'samsung']

# %% [markdown]
# # 3.Load the pretrained model (only the feature extractor)

# %%
img_w,img_h = 224,224 
vgg_extractor = tf.keras.applications.mobilenet.MobileNet(weights = "imagenet", include_top=True,input_shape = (img_w, img_h,3)) 

vgg_extractor.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1, 1, 1024)       0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  conv_preds (Conv2D)         (None, 1, 1, 1000)        1025000
#
#  reshape_2 (Reshape)         (None, 1000)              0
#
#  predictions (Activation)    (None, 1000)              0
#
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# All layer = False
vgg_extractor.trainable = False

# recheck layer.trainable

for i,layer in enumerate(vgg_extractor.layers):  
    print( f"Layer {i}: name = {layer.name} , trainable = {layer.trainable}" )
# Out:
# Layer 0: name = input_1 , trainable = False
# Layer 1: name = conv1 , trainable = False
# Layer 2: name = conv1_bn , trainable = False
# Layer 3: name = conv1_relu , trainable = False
# Layer 4: name = conv_dw_1 , trainable = False
# Layer 5: name = conv_dw_1_bn , trainable = False
# Layer 6: name = conv_dw_1_relu , trainable = False
# Layer 7: name = conv_pw_1 , trainable = False
# Layer 8: name = conv_pw_1_bn , trainable = False
# Layer 9: name = conv_pw_1_relu , trainable = False
# Layer 10: name = conv_pad_2 , trainable = False
# Layer 11: name = conv_dw_2 , trainable = False
# Layer 12: name = conv_dw_2_bn , trainable = False
# Layer 13: name = conv_dw_2_relu , trainable = False
# Layer 14: name = conv_pw_2 , trainable = False
# Layer 15: name = conv_pw_2_bn , trainable = False
# Layer 16: name = conv_pw_2_relu , trainable = False
# Layer 17: name = conv_dw_3 , trainable = False
# Layer 18: name = conv_dw_3_bn , trainable = False
# Layer 19: name = conv_dw_3_relu , trainable = False
# Layer 20: name = conv_pw_3 , trainable = False
# Layer 21: name = conv_pw_3_bn , trainable = False
# Layer 22: name = conv_pw_3_relu , trainable = False
# Layer 23: name = conv_pad_4 , trainable = False
# Layer 24: name = conv_dw_4 , trainable = False
# Layer 25: name = conv_dw_4_bn , trainable = False
# Layer 26: name = conv_dw_4_relu , trainable = False
# Layer 27: name = conv_pw_4 , trainable = False
# Layer 28: name = conv_pw_4_bn , trainable = False
# Layer 29: name = conv_pw_4_relu , trainable = False
# Layer 30: name = conv_dw_5 , trainable = False
# Layer 31: name = conv_dw_5_bn , trainable = False
# Layer 32: name = conv_dw_5_relu , trainable = False
# Layer 33: name = conv_pw_5 , trainable = False
# Layer 34: name = conv_pw_5_bn , trainable = False
# Layer 35: name = conv_pw_5_relu , trainable = False
# Layer 36: name = conv_pad_6 , trainable = False
# Layer 37: name = conv_dw_6 , trainable = False
# Layer 38: name = conv_dw_6_bn , trainable = False
# Layer 39: name = conv_dw_6_relu , trainable = False
# Layer 40: name = conv_pw_6 , trainable = False
# Layer 41: name = conv_pw_6_bn , trainable = False
# Layer 42: name = conv_pw_6_relu , trainable = False
# Layer 43: name = conv_dw_7 , trainable = False
# Layer 44: name = conv_dw_7_bn , trainable = False
# Layer 45: name = conv_dw_7_relu , trainable = False
# Layer 46: name = conv_pw_7 , trainable = False
# Layer 47: name = conv_pw_7_bn , trainable = False
# Layer 48: name = conv_pw_7_relu , trainable = False
# Layer 49: name = conv_dw_8 , trainable = False
# Layer 50: name = conv_dw_8_bn , trainable = False
# Layer 51: name = conv_dw_8_relu , trainable = False
# Layer 52: name = conv_pw_8 , trainable = False
# Layer 53: name = conv_pw_8_bn , trainable = False
# Layer 54: name = conv_pw_8_relu , trainable = False
# Layer 55: name = conv_dw_9 , trainable = False
# Layer 56: name = conv_dw_9_bn , trainable = False
# Layer 57: name = conv_dw_9_relu , trainable = False
# Layer 58: name = conv_pw_9 , trainable = False
# Layer 59: name = conv_pw_9_bn , trainable = False
# Layer 60: name = conv_pw_9_relu , trainable = False
# Layer 61: name = conv_dw_10 , trainable = False
# Layer 62: name = conv_dw_10_bn , trainable = False
# Layer 63: name = conv_dw_10_relu , trainable = False
# Layer 64: name = conv_pw_10 , trainable = False
# Layer 65: name = conv_pw_10_bn , trainable = False
# Layer 66: name = conv_pw_10_relu , trainable = False
# Layer 67: name = conv_dw_11 , trainable = False
# Layer 68: name = conv_dw_11_bn , trainable = False
# Layer 69: name = conv_dw_11_relu , trainable = False
# Layer 70: name = conv_pw_11 , trainable = False
# Layer 71: name = conv_pw_11_bn , trainable = False
# Layer 72: name = conv_pw_11_relu , trainable = False
# Layer 73: name = conv_pad_12 , trainable = False
# Layer 74: name = conv_dw_12 , trainable = False
# Layer 75: name = conv_dw_12_bn , trainable = False
# Layer 76: name = conv_dw_12_relu , trainable = False
# Layer 77: name = conv_pw_12 , trainable = False
# Layer 78: name = conv_pw_12_bn , trainable = False
# Layer 79: name = conv_pw_12_relu , trainable = False
# Layer 80: name = conv_dw_13 , trainable = False
# Layer 81: name = conv_dw_13_bn , trainable = False
# Layer 82: name = conv_dw_13_relu , trainable = False
# Layer 83: name = conv_pw_13 , trainable = False
# Layer 84: name = conv_pw_13_bn , trainable = False
# Layer 85: name = conv_pw_13_relu , trainable = False
# Layer 86: name = global_average_pooling2d , trainable = False
# Layer 87: name = dropout , trainable = False
# Layer 88: name = conv_preds , trainable = False
# Layer 89: name = reshape_2 , trainable = False
# Layer 90: name = predictions , trainable = False

# %% [markdown]
# # 4.Compile and train the model

# %%
# %pwd
# Out:
# '/content'

# %%
initial_learning_rate = 0.0001 # Defaults to 0.001

vgg_extractor.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=initial_learning_rate),
    loss="sparse_categorical_crossentropy",
    metrics=["acc"]
    )

# %%
# %cd "/content/gdrive/MyDrive/DADS_7202/vgg_model/preprocess"

# %%
checkpoint_filepath = "bestmodel_epoch{epoch:02d}_valloss{val_loss:.2f}.hdf5"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                               save_weights_only=False, 
                                                               monitor='val_acc', 
                                                               mode='max',
                                                               save_best_only=True)

# %%
# %%time
history = vgg_extractor.fit(train_ds,
                    batch_size = None,
                    epochs=10, verbose=1,
                    validation_data=val_ds,
                    callbacks=[model_checkpoint_callback]
                    )
# Out:
# Epoch 1/10
# 9/9 [==============================] - 121s 3s/step - loss: 13.4612 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 2/10
# 9/9 [==============================] - 2s 91ms/step - loss: 13.4490 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 3/10
# 9/9 [==============================] - 2s 81ms/step - loss: 13.4475 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 4/10
# 9/9 [==============================] - 2s 80ms/step - loss: 13.4475 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 5/10
# 9/9 [==============================] - 2s 78ms/step - loss: 13.4516 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 6/10
# 9/9 [==============================] - 2s 86ms/step - loss: 13.4619 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 7/10
# 9/9 [==============================] - 2s 79ms/step - loss: 13.4524 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 8/10
# 9/9 [==============================] - 2s 113ms/step - loss: 13.4544 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 9/10
# 9/9 [==============================] - 2s 80ms/step - loss: 13.4632 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# Epoch 10/10
# 9/9 [==============================] - 2s 88ms/step - loss: 13.4551 - acc: 0.0000e+00 - val_loss: 13.5719 - val_acc: 0.0000e+00
# CPU times: user 21.9 s, sys: 2.21 s, total: 24.1 s
# Wall time: 2min 41s

# %%
# %ls
# Out:
# bestmodel_epoch01_valloss13.57.hdf5  gdrive/  sample_data/

# %%
# Check the keys in 'history'
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
# Summarize history for accuracy
plt.figure(figsize=(15,5))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Train accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid()
plt.show()

# Summarize history for loss
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Train loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# # 5.Evaluate the model

# %%
# Evaluate the model
results = vgg_extractor.evaluate(test_ds)
# Out:
# 3/3 [==============================] - 26s 212ms/step - loss: 13.3670 - acc: 0.0000e+00

# %%
print( f"Test results from last model:{vgg_extractor.metrics_names}: {results}\n" )
# Out:
# Test results from last model:['loss', 'acc']: [13.36701774597168, 0.0]

# %% [markdown]
# #6.Inference

# %%
test_ds_u = test_ds.unbatch()

lst_x = []
lst_y = []
for batch_images, batch_labels in test_ds_u :
  A = tf.keras.applications.vgg16.preprocess_input(batch_images)
  B = batch_labels
  lst_x.append(A)
  lst_y.append(B)

x_test = tf.stack(lst_x)
y_test = tf.stack(lst_y)

# %%
x_test.shape
# Out:
# TensorShape([80, 224, 224, 3])

# %%
x_test[0].dtype
# Out:
# tf.float32

# %%
x = tf.keras.applications.vgg16.preprocess_input(x_test)

# %%
# Use the model to predict this image
pred = vgg_extractor.predict(x)  #reshape ก็ได้ เพื่อบอก Batch size
# Out:
# 3/3 [==============================] - 0s 43ms/step

# %%
pred.shape
# Out:
# (80, 1000)

# %%
for j in range(10):
  predictions = tf.keras.applications.mobilenet.decode_predictions(pred, top=5)[j]
  print("Pic", j+1 , "Class: ", class_names[y_test[j]])
  for i, prediction in enumerate(predictions):
    print( f"\tRank {i+1}: {prediction[1],prediction[2]}")
# Out:
# Pic 1 Class:  apple
# 	Rank 1: ('Band_Aid', 0.33808225)
# 	Rank 2: ('envelope', 0.12236065)
# 	Rank 3: ('carton', 0.10680499)
# 	Rank 4: ('mailbag', 0.039833583)
# 	Rank 5: ('wallet', 0.03881733)
# Pic 2 Class:  huawei
# 	Rank 1: ('wallet', 0.25158975)
# 	Rank 2: ('microwave', 0.123779595)
# 	Rank 3: ('binder', 0.09137395)
# 	Rank 4: ('mailbag', 0.056398854)
# 	Rank 5: ('tape_player', 0.055683453)
# Pic 3 Class:  apple
# 	Rank 1: ('wallet', 0.7828528)
# 	Rank 2: ('mailbag', 0.062287312)
# 	Rank 3: ('parachute', 0.031603266)
# 	Rank 4: ('book_jacket', 0.019281434)
# 	Rank 5: ('purse', 0.015697895)
# Pic 4 Class:  oppo
# 	Rank 1: ('binder', 0.17570657)
# 	Rank 2: ('whistle', 0.13295814)
# 	Rank 3: ('pencil_box', 0.07509843)
# 	Rank 4: ('wall_clock', 0.07445655)
# 	Rank 5: ('ballpoint', 0.06234298)
# Pic 5 Class:  oppo
# 	Rank 1: ('modem', 0.56080526)
# 	Rank 2: ('digital_clock', 0.21760704)
# 	Rank 3: ('cassette_player', 0.03955216)
# 	Rank 4: ('joystick', 0.030060356)
# 	Rank 5: ('switch', 0.029685019)
# Pic 6 Class:  apple
# 	Rank 1: ('bib', 0.81767315)
# 	Rank 2: ('envelope', 0.06964414)
# 	Rank 3: ('wallet', 0.04665882)
# 	Rank 4: ('mailbag', 0.013972267)
# 	Rank 5: ('pencil_box', 0.012614611)
# Pic 7 Class:  samsung
# 	Rank 1: ('paintbrush', 0.25676697)
# 	Rank 2: ('handkerchief', 0.1175223)
# 	Rank 3: ('toilet_tissue', 0.07809993)
# 	Rank 4: ('honeycomb', 0.057558615)
# 	Rank 5: ('envelope', 0.05727361)
# Pic 8 Class:  oppo
# 	Rank 1: ('Band_Aid', 0.21021937)
# 	Rank 2: ('loudspeaker', 0.19601648)
# 	Rank 3: ('lighter', 0.17027542)
# 	Rank 4: ('punching_bag', 0.15918238)
# 	Rank 5: ('pencil_box', 0.0361615)
# Pic 9 Class:  oppo
# 	Rank 1: ('digital_clock', 0.43971756)
# 	Rank 2: ('oscilloscope', 0.27637273)
# 	Rank 3: ('wallet', 0.07761424)
# 	Rank 4: ('space_heater', 0.022464262)
# 	Rank 5: ('traffic_light', 0.022401856)
# Pic 10 Class:  samsung
# 	Rank 1: ('loudspeaker', 0.28344)
# 	Rank 2: ('lighter', 0.212513)
# 	Rank 3: ('cleaver', 0.13573776)
# 	Rank 4: ('punching_bag', 0.087333515)
# 	Rank 5: ('switch', 0.02708445)

# %%
plt.figure(figsize=(20, 20))

for i in range(10):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(x_test[i].numpy().astype("uint8"))
  plt.title( class_names[y_test[i]] )
  plt.axis("off")

# %% [markdown]
# # 7.Classification 10 vs Input 4

# %%
# Retrieve a batch of images from the test set
image_batch,label_batch  = test_ds.as_numpy_iterator().next()
predictions = vgg_extractor.predict_on_batch(image_batch) # Returns predictions for a single batch of samples.

# %%
print (type(image_batch),", dtype=",image_batch.dtype,", shape=",image_batch.shape)
print (type(label_batch ),", dtype=",label_batch .dtype,", shape=",label_batch .shape)
# Out:
# <class 'numpy.ndarray'> , dtype= float32 , shape= (32, 224, 224, 3)
# <class 'numpy.ndarray'> , dtype= int32 , shape= (32,)

# %%
for i in range(10):
  print("No.", i, 'Labels:', class_names[label_batch[i]], 'Predictions:', class_names[np.argmax(predictions[i])])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-ca78391152f6> in <module>
#       1 for i in range(10):
# ----> 2   print("No.", i, 'Labels:', class_names[label_batch[i]], 'Predictions:', class_names[np.argmax(predictions[i])])
#
# IndexError: list index out of range

# %%
plt.figure(figsize=(20, 20))

for i in range(20):
  ax = plt.subplot(5, 5, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  plt.title( class_names[label_batch[i]] + "-" +class_names[np.argmax(predictions[i])] )  # y_test y_pred
  plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-8c56d58bad5e> in <module>
#       4   ax = plt.subplot(5, 5, i + 1)
#       5   plt.imshow(image_batch[i].astype("uint8"))
# ----> 6   plt.title( class_names[label_batch[i]] + "-" +class_names[np.argmax(predictions[i])] )  # y_test y_pred
#       7   plt.axis("off")
#
# IndexError: list index out of range

# %% [markdown]
# # 8.Download model

# %%
# !cp bestmodel_epoch01_valloss13.57.hdf5 /content/gdrive/MyDrive
